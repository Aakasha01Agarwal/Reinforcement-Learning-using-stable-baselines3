# %% [markdown]
# # Dependencies

# %%
import os
import gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env

# %% [markdown]
# # Enviroment

# %%
# !python -m atari_py.import_roms .\ROMS
# Out:
# copying adventure.bin from .\ROMS\Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\adventure.bin
# copying air_raid.bin from .\ROMS\Air Raid (Men-A-Vision) (PAL) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\air_raid.bin
# copying alien.bin from .\ROMS\Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\alien.bin
# copying amidar.bin from .\ROMS\Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\amidar.bin
# copying assault.bin from .\ROMS\Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\assault.bin
# copying asterix.bin from .\ROMS\Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\asterix.bin
# copying asteroids.bin from .\ROMS\Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\asteroids.bin
# copying atlantis.bin from .\ROMS\Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\atlantis.bin
# copying bank_heist.bin from .\ROMS\Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\bank_heist.bin
# copying battle_zone.bin from .\ROMS\Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\battle_zone.bin
# copying beam_rider.bin from .\ROMS\Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\beam_rider.bin
# copying berzerk.bin from .\ROMS\Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\berzerk.bin
# copying bowling.bin from .\ROMS\Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\bowling.bin
# copying boxing.bin from .\ROMS\Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\boxing.bin
# copying breakout.bin from .\ROMS\Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\breakout.bin
# copying carnival.bin from .\ROMS\Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\carnival.bin
# copying centipede.bin from .\ROMS\Centipede (1983) (Atari - GCC) (CX2676) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\centipede.bin
# copying chopper_command.bin from .\ROMS\Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\chopper_command.bin
# copying crazy_climber.bin from .\ROMS\Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\crazy_climber.bin
# copying defender.bin from .\ROMS\Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\defender.bin
# copying demon_attack.bin from .\ROMS\Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\demon_attack.bin
# copying donkey_kong.bin from .\ROMS\Donkey Kong (1982) (Coleco - Woodside Design Associates - Imaginative Systems Software, Garry Kitchen) (2451) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\donkey_kong.bin
# copying double_dunk.bin from .\ROMS\Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\double_dunk.bin
# copying elevator_action.bin from .\ROMS\Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\elevator_action.bin
# copying enduro.bin from .\ROMS\Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\enduro.bin
# copying fishing_derby.bin from .\ROMS\Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\fishing_derby.bin
# copying freeway.bin from .\ROMS\Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\freeway.bin
# copying frogger.bin from .\ROMS\Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\frogger.bin
# copying frostbite.bin from .\ROMS\Frostbite (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\frostbite.bin
# copying galaxian.bin from .\ROMS\Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\galaxian.bin
# copying gopher.bin from .\ROMS\Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\gopher.bin
# copying gravitar.bin from .\ROMS\Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\gravitar.bin
# copying hero.bin from .\ROMS\H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\hero.bin
# copying ice_hockey.bin from .\ROMS\Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\ice_hockey.bin
# copying jamesbond.bin from .\ROMS\James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Louis Marbel) (PB5110) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\jamesbond.bin
# copying journey_escape.bin from .\ROMS\Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\journey_escape.bin
# copying kaboom.bin from .\ROMS\Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, AG-010-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\kaboom.bin
# copying kangaroo.bin from .\ROMS\Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\kangaroo.bin
# copying keystone_kapers.bin from .\ROMS\Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\keystone_kapers.bin
# copying king_kong.bin from .\ROMS\King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\king_kong.bin
# copying koolaid.bin from .\ROMS\Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\koolaid.bin
# copying krull.bin from .\ROMS\Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\krull.bin
# copying kung_fu_master.bin from .\ROMS\Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\kung_fu_master.bin
# copying laser_gates.bin from .\ROMS\Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\laser_gates.bin
# copying lost_luggage.bin from .\ROMS\Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\lost_luggage.bin
# copying montezuma_revenge.bin from .\ROMS\Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\montezuma_revenge.bin
# copying mr_do.bin from .\ROMS\Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\mr_do.bin
# copying ms_pacman.bin from .\ROMS\Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\ms_pacman.bin
# copying name_this_game.bin from .\ROMS\Name This Game (Guardians of Treasure) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\name_this_game.bin
# copying pacman.bin from .\ROMS\Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\pacman.bin
# copying phoenix.bin from .\ROMS\Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\phoenix.bin
# copying video_pinball.bin from .\ROMS\Pinball (AKA Video Pinball) (Zellers).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\video_pinball.bin
# copying pitfall.bin from .\ROMS\Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\pitfall.bin
# copying pooyan.bin from .\ROMS\Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\pooyan.bin
# copying private_eye.bin from .\ROMS\Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\private_eye.bin
# copying qbert.bin from .\ROMS\Q-bert (1983) (Parker Brothers - Western Technologies, Dave Hampton, Tom Sloper) (PB5360) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\qbert.bin
# copying riverraid.bin from .\ROMS\River Raid (1982) (Activision, Carol Shaw) (AX-020, AX-020-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\riverraid.bin
# copying road_runner.bin from patched version of .\ROMS\Road Runner (1989) (Atari - Bobco, Robert C. Polaro) (CX2663) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\road_runner.bin
# copying robotank.bin from .\ROMS\Robot Tank (Robotank) (1983) (Activision, Alan Miller) (AZ-028, AG-028-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\robotank.bin
# copying seaquest.bin from .\ROMS\Seaquest (1983) (Activision, Steve Cartwright) (AX-022) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\seaquest.bin
# copying sir_lancelot.bin from .\ROMS\Sir Lancelot (1983) (Xonox - K-Tel Software - Product Guild, Anthony R. Henderson) (99006, 6220) (PAL).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\sir_lancelot.bin
# copying skiing.bin from .\ROMS\Skiing - Le Ski (1980) (Activision, Bob Whitehead) (AG-005, CAG-005, AG-005-04) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\skiing.bin
# copying solaris.bin from .\ROMS\Solaris (The Last Starfighter, Star Raiders II, Universe) (1986) (Atari, Douglas Neubauer, Mimi Nyden) (CX26136) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\solaris.bin
# copying space_invaders.bin from .\ROMS\Space Invaders (1980) (Atari, Richard Maurer - Sears) (CX2632 - 49-75153) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\space_invaders.bin
# copying star_gunner.bin from .\ROMS\Stargunner (1983) (Telesys, Alex Leavens) (1005) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\star_gunner.bin
# copying surround.bin from .\ROMS\Surround (32 in 1) (Bit Corporation) (R320).bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\surround.bin
# copying tennis.bin from .\ROMS\Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\tennis.bin
# copying time_pilot.bin from .\ROMS\Time Pilot (1983) (Coleco - Woodside Design Associates, Harley H. Puthuff Jr.) (2663) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\time_pilot.bin
# copying trondead.bin from .\ROMS\TRON - Deadly Discs (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Jeff Ronne, Brett Stutz) (MT5662) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\trondead.bin
# copying tutankham.bin from .\ROMS\Tutankham (1983) (Parker Brothers, Dave Engman, Dawn Stockbridge) (PB5340) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\tutankham.bin
# copying up_n_down.bin from .\ROMS\Up 'n Down (1984) (SEGA - Beck-Tech, Steve Beck, Phat Ho) (009-01) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\up_n_down.bin
# copying venture.bin from .\ROMS\Venture (1982) (Coleco, Joseph Biel) (2457) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\venture.bin
# copying pong.bin from .\ROMS\Video Olympics - Pong Sports (Paddle) (1977) (Atari, Joe Decuir - Sears) (CX2621 - 99806, 6-99806, 49-75104) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\pong.bin
# copying wizard_of_wor.bin from .\ROMS\Wizard of Wor (1982) (CBS Electronics - Roklan, Joe Hellesen, Joe Wagner) (M8774, M8794) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\wizard_of_wor.bin
# copying yars_revenge.bin from .\ROMS\Yars' Revenge (Time Freeze) (1982) (Atari, Howard Scott Warshaw - Sears) (CX2655 - 49-75167) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\yars_revenge.bin
# copying zaxxon.bin from .\ROMS\Zaxxon (1983) (Coleco) (2454) ~.bin to C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\atari_py\atari_roms\zaxxon.bin

# %%
environment_name = "Breakout-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\atari\environment.py:255: UserWarning: WARN: We strongly suggest supplying `render_mode` when constructing your environment, e.g., gym.make(ID, render_mode='human'). Using `render_mode` provides access to proper scaling, audio support, and proper framerates.
#   logger.warn(
# C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# Episode:1 Score:0.0
# Episode:2 Score:0.0
# Episode:3 Score:0.0
# Episode:4 Score:0.0
# Episode:5 Score:3.0

# %%
env.action_space
# Out:
# Discrete(4)

# %%
env.observation_space.sample()
# Out:
# array([[[135,  64, 189],
#         [ 14, 197, 226],
#         [223, 133,  38],
#         ...,
#         [ 39,  19, 199],
#         [ 45,  67, 194],
#         [ 71, 123, 116]],
#
#        [[ 35,  54, 121],
#         [ 40,  35, 151],
#         [ 66,  21, 167],
#         ...,
#         [200,  66, 171],
#         [ 85, 100, 128],
#         [240, 210,   7]],
#
#        [[119, 187, 219],
#         [  7,  94, 119],
#         [136, 157,  66],
#         ...,
#         [  2, 194, 223],
#         [173,  19, 227],
#         [  7, 243, 111]],
#
#        ...,
#
#        [[149,  45,  47],
#         [ 11, 199, 218],
#         [160, 197, 217],
#         ...,
#         [231, 153,  22],
#         [202,  52, 234],
#         [184,  47, 174]],
#
#        [[ 59,  22, 134],
#         [163,  68,  29],
#         [137, 176, 142],
#         ...,
#         [134, 248, 213],
#         [ 71,  57, 171],
#         [  0, 163, 175]],
#
#        [[ 51, 180,  20],
#         [ 69,  40,  66],
#         [ 92, 205,  29],
#         ...,
#         [186, 254, 208],
#         [103, 161,  56],
#         [163, 164, 217]]], dtype=uint8)

# %% [markdown]
# # Vectorize the Environment

# %%
env = make_atari_env('Breakout-v0', n_envs=4, seed=0)

# %%
env = VecFrameStack(env, n_stack=4)

# %%
log_path = os.path.join('Training', 'Logs')
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training\Logs\A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 290      |
# |    ep_rew_mean        | 1.6      |
# | time/                 |          |
# |    fps                | 88       |
# |    iterations         | 100      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.247    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0152   |
# |    value_loss         | 0.00234  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 289      |
# |    ep_rew_mean        | 1.62     |
# | time/                 |          |
# |    fps                | 114      |
# |    iterations         | 200      |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.00659  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.207    |
# |    value_loss         | 0.241    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.72     |
# | time/                 |          |
# |    fps                | 129      |
# |    iterations         | 300      |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.752    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0351  |
# |    value_loss         | 0.00941  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 300      |
# |    ep_rew_mean        | 1.89     |
# | time/                 |          |
# |    fps                | 137      |
# |    iterations         | 400      |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.85     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0899   |
# |    value_loss         | 0.0683   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 306      |
# |    ep_rew_mean        | 2.03     |
# | time/                 |          |
# |    fps                | 142      |
# |    iterations         | 500      |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.976   |
# |    explained_variance | 0.932    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0512   |
# |    value_loss         | 0.0371   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 2.01     |
# | time/                 |          |
# |    fps                | 145      |
# |    iterations         | 600      |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.53    |
# |    explained_variance | 0.864    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0354  |
# |    value_loss         | 0.0625   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 299      |
# |    ep_rew_mean        | 1.9      |
# | time/                 |          |
# |    fps                | 147      |
# |    iterations         | 700      |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0323  |
# |    value_loss         | 0.025    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 299      |
# |    ep_rew_mean        | 1.91     |
# | time/                 |          |
# |    fps                | 150      |
# |    iterations         | 800      |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.826    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0424   |
# |    value_loss         | 0.0978   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 314      |
# |    ep_rew_mean        | 2.24     |
# | time/                 |          |
# |    fps                | 153      |
# |    iterations         | 900      |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.02    |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0211  |
# |    value_loss         | 0.0358   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 327      |
# |    ep_rew_mean        | 2.48     |
# | time/                 |          |
# |    fps                | 154      |
# |    iterations         | 1000     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0211   |
# |    value_loss         | 0.00722  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 333      |
# |    ep_rew_mean        | 2.61     |
# | time/                 |          |
# |    fps                | 156      |
# |    iterations         | 1100     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.26    |
# |    explained_variance | 0.586    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.269   |
# |    value_loss         | 0.137    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 339      |
# |    ep_rew_mean        | 2.69     |
# | time/                 |          |
# |    fps                | 158      |
# |    iterations         | 1200     |
# |    time_elapsed       | 151      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.88     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.113   |
# |    value_loss         | 0.0311   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 332      |
# |    ep_rew_mean        | 2.54     |
# | time/                 |          |
# |    fps                | 159      |
# |    iterations         | 1300     |
# |    time_elapsed       | 162      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0648   |
# |    value_loss         | 0.00777  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 332      |
# |    ep_rew_mean        | 2.52     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 1400     |
# |    time_elapsed       | 173      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | 0.942    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.107    |
# |    value_loss         | 0.0215   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 334      |
# |    ep_rew_mean        | 2.58     |
# | time/                 |          |
# |    fps                | 162      |
# |    iterations         | 1500     |
# |    time_elapsed       | 184      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0.136    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.0362   |
# |    value_loss         | 0.119    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 338      |
# |    ep_rew_mean        | 2.74     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 1600     |
# |    time_elapsed       | 194      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.656    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0432  |
# |    value_loss         | 0.166    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 330      |
# |    ep_rew_mean        | 2.7      |
# | time/                 |          |
# |    fps                | 165      |
# |    iterations         | 1700     |
# |    time_elapsed       | 205      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.899   |
# |    explained_variance | -0.431   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.166    |
# |    value_loss         | 0.159    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 344      |
# |    ep_rew_mean        | 3.07     |
# | time/                 |          |
# |    fps                | 167      |
# |    iterations         | 1800     |
# |    time_elapsed       | 214      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.494   |
# |    explained_variance | 0.897    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0662   |
# |    value_loss         | 0.0747   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 366      |
# |    ep_rew_mean        | 3.53     |
# | time/                 |          |
# |    fps                | 169      |
# |    iterations         | 1900     |
# |    time_elapsed       | 224      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.612   |
# |    explained_variance | 0.521    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.00173  |
# |    value_loss         | 0.336    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 386      |
# |    ep_rew_mean        | 3.97     |
# | time/                 |          |
# |    fps                | 171      |
# |    iterations         | 2000     |
# |    time_elapsed       | 233      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.346   |
# |    explained_variance | 0.812    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0397  |
# |    value_loss         | 0.088    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 419      |
# |    ep_rew_mean        | 4.58     |
# | time/                 |          |
# |    fps                | 173      |
# |    iterations         | 2100     |
# |    time_elapsed       | 242      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.308   |
# |    explained_variance | 0.842    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.12    |
# |    value_loss         | 0.073    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 441      |
# |    ep_rew_mean        | 5.01     |
# | time/                 |          |
# |    fps                | 174      |
# |    iterations         | 2200     |
# |    time_elapsed       | 251      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.359   |
# |    explained_variance | 0.849    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.000595 |
# |    value_loss         | 0.266    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 5.25     |
# | time/                 |          |
# |    fps                | 176      |
# |    iterations         | 2300     |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.321   |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.048    |
# |    value_loss         | 0.0521   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | 5.4      |
# | time/                 |          |
# |    fps                | 177      |
# |    iterations         | 2400     |
# |    time_elapsed       | 270      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.549   |
# |    explained_variance | 0.844    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.028   |
# |    value_loss         | 0.0256   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 426      |
# |    ep_rew_mean        | 4.59     |
# | time/                 |          |
# |    fps                | 178      |
# |    iterations         | 2500     |
# |    time_elapsed       | 280      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.24    |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0109   |
# |    value_loss         | 0.00955  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 413      |
# |    ep_rew_mean        | 4.22     |
# | time/                 |          |
# |    fps                | 179      |
# |    iterations         | 2600     |
# |    time_elapsed       | 290      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.753   |
# |    explained_variance | 0.821    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.257    |
# |    value_loss         | 0.224    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 409      |
# |    ep_rew_mean        | 4.12     |
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 2700     |
# |    time_elapsed       | 299      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.674   |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0262  |
# |    value_loss         | 0.0563   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 408      |
# |    ep_rew_mean        | 4.08     |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 2800     |
# |    time_elapsed       | 309      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.748   |
# |    explained_variance | 0.89     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.168   |
# |    value_loss         | 0.0537   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 424      |
# |    ep_rew_mean        | 4.47     |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 2900     |
# |    time_elapsed       | 320      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.53    |
# |    explained_variance | 0.782    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.165    |
# |    value_loss         | 0.0907   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 452      |
# |    ep_rew_mean        | 5.11     |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 3000     |
# |    time_elapsed       | 330      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.669   |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0166   |
# |    value_loss         | 0.0355   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 466      |
# |    ep_rew_mean        | 5.46     |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 3100     |
# |    time_elapsed       | 339      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.127    |
# |    value_loss         | 0.027    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 463      |
# |    ep_rew_mean        | 5.45     |
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 3200     |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.904   |
# |    explained_variance | 0.869    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0193   |
# |    value_loss         | 0.0497   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 457      |
# |    ep_rew_mean        | 5.38     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 3300     |
# |    time_elapsed       | 358      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.458   |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0271  |
# |    value_loss         | 0.0364   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 450      |
# |    ep_rew_mean        | 5.26     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 3400     |
# |    time_elapsed       | 367      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.797   |
# |    explained_variance | 0.925    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.00829 |
# |    value_loss         | 0.0286   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | 5.46     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 3500     |
# |    time_elapsed       | 377      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.963   |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.00255  |
# |    value_loss         | 0.056    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 464      |
# |    ep_rew_mean        | 5.51     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 3600     |
# |    time_elapsed       | 388      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.455   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.000187 |
# |    value_loss         | 0.0657   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 475      |
# |    ep_rew_mean        | 5.72     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 3700     |
# |    time_elapsed       | 399      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.729   |
# |    explained_variance | 0.727    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0901  |
# |    value_loss         | 0.0818   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 489      |
# |    ep_rew_mean        | 6.04     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 3800     |
# |    time_elapsed       | 410      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.512   |
# |    explained_variance | 0.508    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0306  |
# |    value_loss         | 0.0464   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 498      |
# |    ep_rew_mean        | 6.33     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 3900     |
# |    time_elapsed       | 420      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.83    |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.123    |
# |    value_loss         | 0.202    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 507      |
# |    ep_rew_mean        | 6.51     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 4000     |
# |    time_elapsed       | 431      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.478   |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.0164  |
# |    value_loss         | 0.0179   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 517      |
# |    ep_rew_mean        | 6.78     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 4100     |
# |    time_elapsed       | 442      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.589   |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.0392   |
# |    value_loss         | 0.0344   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 523      |
# |    ep_rew_mean        | 6.91     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 4200     |
# |    time_elapsed       | 453      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | 0.588    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0947  |
# |    value_loss         | 0.164    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 518      |
# |    ep_rew_mean        | 6.71     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 4300     |
# |    time_elapsed       | 464      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.365   |
# |    explained_variance | 0.857    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.00597  |
# |    value_loss         | 0.0591   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 524      |
# |    ep_rew_mean        | 6.84     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 4400     |
# |    time_elapsed       | 475      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.696   |
# |    explained_variance | 0.873    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0187  |
# |    value_loss         | 0.039    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 516      |
# |    ep_rew_mean        | 6.6      |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 4500     |
# |    time_elapsed       | 486      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.364   |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.0499   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 510      |
# |    ep_rew_mean        | 6.4      |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 4600     |
# |    time_elapsed       | 497      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.399   |
# |    explained_variance | 0.823    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0453   |
# |    value_loss         | 0.0358   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 513      |
# |    ep_rew_mean        | 6.46     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 4700     |
# |    time_elapsed       | 508      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | 0.794    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.186    |
# |    value_loss         | 0.348    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 512      |
# |    ep_rew_mean        | 6.47     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 4800     |
# |    time_elapsed       | 519      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.831   |
# |    explained_variance | 0.675    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.309    |
# |    value_loss         | 0.154    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 519      |
# |    ep_rew_mean        | 6.55     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 4900     |
# |    time_elapsed       | 530      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.606   |
# |    explained_variance | 0.975    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.058   |
# |    value_loss         | 0.0375   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 516      |
# |    ep_rew_mean        | 6.43     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 5000     |
# |    time_elapsed       | 542      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.596   |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0862  |
# |    value_loss         | 0.109    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | 6.71     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 5100     |
# |    time_elapsed       | 553      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -0.506   |
# |    explained_variance | 0.412    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.16    |
# |    value_loss         | 0.421    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 534      |
# |    ep_rew_mean        | 6.84     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 5200     |
# |    time_elapsed       | 564      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.452   |
# |    explained_variance | 0.832    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.0598   |
# |    value_loss         | 0.0473   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 537      |
# |    ep_rew_mean        | 6.92     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 5300     |
# |    time_elapsed       | 573      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -0.679   |
# |    explained_variance | 0.882    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.0157   |
# |    value_loss         | 0.0315   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 545      |
# |    ep_rew_mean        | 7.02     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 5400     |
# |    time_elapsed       | 583      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.411   |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.108    |
# |    value_loss         | 0.0964   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 542      |
# |    ep_rew_mean        | 7.11     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 5500     |
# |    time_elapsed       | 592      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -0.337   |
# |    explained_variance | 0.897    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0222   |
# |    value_loss         | 0.0989   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 553      |
# |    ep_rew_mean        | 7.4      |
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 5600     |
# |    time_elapsed       | 601      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.437   |
# |    explained_variance | 0.911    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.0106  |
# |    value_loss         | 0.0229   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 550      |
# |    ep_rew_mean        | 7.39     |
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 5700     |
# |    time_elapsed       | 610      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -0.581   |
# |    explained_variance | 0.78     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.00652 |
# |    value_loss         | 0.0622   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 546      |
# |    ep_rew_mean        | 7.43     |
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 5800     |
# |    time_elapsed       | 620      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.442   |
# |    explained_variance | 0.921    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.00703  |
# |    value_loss         | 0.0631   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 544      |
# |    ep_rew_mean        | 7.35     |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 5900     |
# |    time_elapsed       | 630      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -0.384   |
# |    explained_variance | 0.907    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.0267  |
# |    value_loss         | 0.0776   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 530      |
# |    ep_rew_mean        | 7.16     |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 6000     |
# |    time_elapsed       | 640      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.375   |
# |    explained_variance | 0.876    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0628   |
# |    value_loss         | 0.0441   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 7.3      |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 6100     |
# |    time_elapsed       | 649      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.0528   |
# |    value_loss         | 0.0347   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 550      |
# |    ep_rew_mean        | 7.36     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 6200     |
# |    time_elapsed       | 658      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.344   |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0524  |
# |    value_loss         | 0.0393   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 546      |
# |    ep_rew_mean        | 7.28     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 6300     |
# |    time_elapsed       | 667      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0167  |
# |    value_loss         | 0.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 549      |
# |    ep_rew_mean        | 7.33     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 6400     |
# |    time_elapsed       | 676      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.344   |
# |    explained_variance | 0.921    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.102   |
# |    value_loss         | 0.0819   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 549      |
# |    ep_rew_mean        | 7.35     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 6500     |
# |    time_elapsed       | 687      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -0.283   |
# |    explained_variance | 0.773    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0449  |
# |    value_loss         | 0.108    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 556      |
# |    ep_rew_mean        | 7.46     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 6600     |
# |    time_elapsed       | 697      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.309   |
# |    explained_variance | 0.807    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.00129 |
# |    value_loss         | 0.211    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 551      |
# |    ep_rew_mean        | 7.31     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 6700     |
# |    time_elapsed       | 709      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0631  |
# |    value_loss         | 0.196    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 549      |
# |    ep_rew_mean        | 7.33     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 6800     |
# |    time_elapsed       | 720      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.451   |
# |    explained_variance | 0.801    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.0565   |
# |    value_loss         | 0.182    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 558      |
# |    ep_rew_mean        | 7.45     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 6900     |
# |    time_elapsed       | 732      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -0.286   |
# |    explained_variance | 0.897    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.00477  |
# |    value_loss         | 0.0935   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 565      |
# |    ep_rew_mean        | 7.55     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 7000     |
# |    time_elapsed       | 742      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | 0.903    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.00929 |
# |    value_loss         | 0.212    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 565      |
# |    ep_rew_mean        | 7.65     |
# | time/                 |          |
# |    fps                | 188      |
# |    iterations         | 7100     |
# |    time_elapsed       | 751      |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -0.465   |
# |    explained_variance | 0.715    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.133   |
# |    value_loss         | 0.251    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 560      |
# |    ep_rew_mean        | 7.63     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 7200     |
# |    time_elapsed       | 760      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.238   |
# |    explained_variance | 0.795    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.0249   |
# |    value_loss         | 0.0889   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 568      |
# |    ep_rew_mean        | 7.84     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 7300     |
# |    time_elapsed       | 769      |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -0.261   |
# |    explained_variance | 0.864    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.000318 |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 573      |
# |    ep_rew_mean        | 7.95     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 7400     |
# |    time_elapsed       | 779      |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.431   |
# |    explained_variance | 0.91     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.0159   |
# |    value_loss         | 0.0383   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 567      |
# |    ep_rew_mean        | 7.81     |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 7500     |
# |    time_elapsed       | 788      |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -0.168   |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.00147  |
# |    value_loss         | 0.0198   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 566      |
# |    ep_rew_mean        | 7.85     |
# | time/                 |          |
# |    fps                | 190      |
# |    iterations         | 7600     |
# |    time_elapsed       | 797      |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.261   |
# |    explained_variance | 0.929    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.0072   |
# |    value_loss         | 0.0798   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 571      |
# |    ep_rew_mean        | 7.89     |
# ...
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16099    |
# |    policy_loss        | 0.0163   |
# |    value_loss         | 0.139    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 710      |
# |    ep_rew_mean        | 11.1     |
# | time/                 |          |
# |    fps                | 195      |
# |    iterations         | 16200    |
# |    time_elapsed       | 1661     |
# |    total_timesteps    | 324000   |
# | train/                |          |
# |    entropy_loss       | -0.104   |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16199    |
# |    policy_loss        | 0.00814  |
# |    value_loss         | 0.0325   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 710      |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 16300    |
# |    time_elapsed       | 1672     |
# |    total_timesteps    | 326000   |
# | train/                |          |
# |    entropy_loss       | -0.0504  |
# |    explained_variance | 0.809    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16299    |
# |    policy_loss        | -0.125   |
# |    value_loss         | 0.286    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 700      |
# |    ep_rew_mean        | 11       |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 16400    |
# |    time_elapsed       | 1683     |
# |    total_timesteps    | 328000   |
# | train/                |          |
# |    entropy_loss       | -0.187   |
# |    explained_variance | 0.931    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16399    |
# |    policy_loss        | 0.0662   |
# |    value_loss         | 0.0761   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 694      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 16500    |
# |    time_elapsed       | 1695     |
# |    total_timesteps    | 330000   |
# | train/                |          |
# |    entropy_loss       | -0.093   |
# |    explained_variance | 0.925    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16499    |
# |    policy_loss        | -0.00242 |
# |    value_loss         | 0.0211   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 703      |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 16600    |
# |    time_elapsed       | 1707     |
# |    total_timesteps    | 332000   |
# | train/                |          |
# |    entropy_loss       | -0.131   |
# |    explained_variance | 0.848    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16599    |
# |    policy_loss        | -0.0285  |
# |    value_loss         | 0.198    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 698      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 16700    |
# |    time_elapsed       | 1718     |
# |    total_timesteps    | 334000   |
# | train/                |          |
# |    entropy_loss       | -0.0879  |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16699    |
# |    policy_loss        | -0.0223  |
# |    value_loss         | 0.0461   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 699      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 16800    |
# |    time_elapsed       | 1729     |
# |    total_timesteps    | 336000   |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | 0.823    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16799    |
# |    policy_loss        | -0.0704  |
# |    value_loss         | 0.422    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 689      |
# |    ep_rew_mean        | 10.4     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 16900    |
# |    time_elapsed       | 1740     |
# |    total_timesteps    | 338000   |
# | train/                |          |
# |    entropy_loss       | -0.103   |
# |    explained_variance | 0.871    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16899    |
# |    policy_loss        | -0.00626 |
# |    value_loss         | 0.101    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 689      |
# |    ep_rew_mean        | 10.4     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17000    |
# |    time_elapsed       | 1751     |
# |    total_timesteps    | 340000   |
# | train/                |          |
# |    entropy_loss       | -0.269   |
# |    explained_variance | 0.0168   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 16999    |
# |    policy_loss        | -0.0408  |
# |    value_loss         | 0.328    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 692      |
# |    ep_rew_mean        | 10.5     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17100    |
# |    time_elapsed       | 1762     |
# |    total_timesteps    | 342000   |
# | train/                |          |
# |    entropy_loss       | -0.16    |
# |    explained_variance | 0.635    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17099    |
# |    policy_loss        | -0.00746 |
# |    value_loss         | 0.192    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 700      |
# |    ep_rew_mean        | 10.6     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17200    |
# |    time_elapsed       | 1772     |
# |    total_timesteps    | 344000   |
# | train/                |          |
# |    entropy_loss       | -0.0565  |
# |    explained_variance | 0.92     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17199    |
# |    policy_loss        | -0.00336 |
# |    value_loss         | 0.0971   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 709      |
# |    ep_rew_mean        | 10.8     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17300    |
# |    time_elapsed       | 1782     |
# |    total_timesteps    | 346000   |
# | train/                |          |
# |    entropy_loss       | -0.0597  |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17299    |
# |    policy_loss        | 0.0109   |
# |    value_loss         | 0.0464   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 707      |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17400    |
# |    time_elapsed       | 1792     |
# |    total_timesteps    | 348000   |
# | train/                |          |
# |    entropy_loss       | -0.0898  |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17399    |
# |    policy_loss        | -0.00449 |
# |    value_loss         | 0.0383   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 709      |
# |    ep_rew_mean        | 10.9     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17500    |
# |    time_elapsed       | 1802     |
# |    total_timesteps    | 350000   |
# | train/                |          |
# |    entropy_loss       | -0.0361  |
# |    explained_variance | 0.728    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17499    |
# |    policy_loss        | 0.0646   |
# |    value_loss         | 0.351    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 721      |
# |    ep_rew_mean        | 11.3     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17600    |
# |    time_elapsed       | 1811     |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -0.152   |
# |    explained_variance | 0.12     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17599    |
# |    policy_loss        | 0.00385  |
# |    value_loss         | 0.163    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 722      |
# |    ep_rew_mean        | 11.5     |
# | time/                 |          |
# |    fps                | 194      |
# |    iterations         | 17700    |
# |    time_elapsed       | 1820     |
# |    total_timesteps    | 354000   |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | 0.849    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | -0.0825  |
# |    value_loss         | 0.464    |
# ------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <module>
# ----> 1 model.learn(total_timesteps=400000)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\a2c\a2c.py:191, in A2C.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     178 def learn(
#     179     self,
#     180     total_timesteps: int,
#    (...)
#     188     reset_num_timesteps: bool = True,
#     189 ) -> "A2C":
# --> 191     return super(A2C, self).learn(
#     192         total_timesteps=total_timesteps,
#     193         callback=callback,
#     194         log_interval=log_interval,
#     195         eval_env=eval_env,
#     196         eval_freq=eval_freq,
#     197         n_eval_episodes=n_eval_episodes,
#     198         tb_log_name=tb_log_name,
#     199         eval_log_path=eval_log_path,
#     200         reset_num_timesteps=reset_num_timesteps,
#     201     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:250, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     246 callback.on_training_start(locals(), globals())
#     248 while self.num_timesteps < total_timesteps:
# --> 250     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     252     if continue_training is False:
#     253         break
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 if isinstance(self.action_space, gym.spaces.Box):
#     176     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 178 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     180 self.num_timesteps += env.num_envs
#     182 # Give access to local variables
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py:95, in VecTransposeImage.step_wait(self)
#      94 def step_wait(self) -> VecEnvStepReturn:
# ---> 95     observations, rewards, dones, infos = self.venv.step_wait()
#      97     # Transpose the terminal observations
#      98     for idx, done in enumerate(dones):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:48, in VecFrameStack.step_wait(self)
#      44 def step_wait(
#      45     self,
#      46 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 48     observations, rewards, dones, infos = self.venv.step_wait()
#      50     observations, infos = self.stackedobs.update(observations, dones, infos)
#      52     return observations, rewards, dones, infos
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\core.py:289, in Wrapper.step(self, action)
#     288 def step(self, action):
# --> 289     return self.env.step(action)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\core.py:336, in RewardWrapper.step(self, action)
#     335 def step(self, action):
# --> 336     observation, reward, done, info = self.env.step(action)
#     337     return observation, self.reward(reward), done, info
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\core.py:323, in ObservationWrapper.step(self, action)
#     322 def step(self, action):
# --> 323     observation, reward, done, info = self.env.step(action)
#     324     return self.observation(observation), reward, done, info
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\core.py:289, in Wrapper.step(self, action)
#     288 def step(self, action):
# --> 289     return self.env.step(action)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\atari_wrappers.py:83, in EpisodicLifeEnv.step(self, action)
#      82 def step(self, action: int) -> GymStepReturn:
# ---> 83     obs, reward, done, info = self.env.step(action)
#      84     self.was_real_done = done
#      85     # check current lives, make loss of life terminal,
#      86     # then update lives to handle bonus lives
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\atari_wrappers.py:143, in MaxAndSkipEnv.step(self, action)
#     141     self._obs_buffer[0] = obs
#     142 if i == self._skip - 1:
# --> 143     self._obs_buffer[1] = obs
#     144 total_reward += reward
#     145 if done:
#
# KeyboardInterrupt:

# %% [markdown]
# # Saving the model

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'A2C_model')

# %%
model.save(a2c_path)

# %%
evaluate_policy(model, env, n_eval_episodes=100, render=True)

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()

# %%
env.close()
