# %% [markdown]
# # Dependencies

# %%
# !pip install stable-baselines3[extra]

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# !pip install gym

# %% [markdown]
# # Enviroment

# %%
environment_name = "CartPole-v0"
env = gym.make(environment_name)

# %%
episodes = 5

for episode in range(1, episodes+1):
    state= env.reset()
    done = False
    score =0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
        
    print("Episode: {}  SCore: {}".format(episode, score))
env.close()
# Out:
# Episode: 1  SCore: 15.0
# Episode: 2  SCore: 16.0
# Episode: 3  SCore: 42.0
# Episode: 4  SCore: 15.0
# Episode: 5  SCore: 17.0

# %%
env.action_space

# %%
env.observation_space

# %%
env.reset()

# %%
env.step(1)

# %% [markdown]
# # More about the Environment
# ### Action Space ###
# * 0 means push to left
# * 1 means push to right
#
# ### Environment Space ###
# * [Cart position, Cart_velocity, Pole_angle, Pole_angular_veolcity ]

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observation_space.sample()
# Out:
# array([-3.0742645e-01,  9.6569902e+36,  3.5095313e-01, -5.5384040e+37],
#       dtype=float32)

# %% [markdown]
# # Training

# %%
# 
log_path = os.path.join('training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO("MlpPolicy", env, verbose =1, tensorboard_log= log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to training\Logs\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 3282 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2076        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008115207 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -0.00122    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.13        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1900        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008127449 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0711      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1766        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008008083 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 53          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1699        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009919431 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 62.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1634        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007852284 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 58.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1612       |
# |    iterations           | 7          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00449865 |
# |    clip_fraction        | 0.0314     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.578     |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 19.3       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0063    |
# |    value_loss           | 53.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1598       |
# |    iterations           | 8          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00779716 |
# |    clip_fraction        | 0.0478     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.571     |
# |    explained_variance   | 0.411      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.8       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00756   |
# |    value_loss           | 49.7       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1583         |
# |    iterations           | 9            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0064973873 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.811        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 28.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1573        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010993466 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.69        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 32          |
# -----------------------------------------

# %% [markdown]
# # Saving and Loading the model

# %%
PPO_path = os.path.join('training', 'saved_models', 'PPO_Model_CartPole')

# %%
PPO_path
# Out:
# 'training\\saved_models\\PPO_Model_CartPole'

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path, env= env)

# %%
model

# %% [markdown]
# # Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes= 10, render = True)
# Out:
# C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# # Testing the model

# %%
episodes = 10

for episode in range(1, episodes+1):
    obs= env.reset()
    done = False
    score =0 
    
    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score+=reward
        
    print("Episode: {}  SCore: {}".format(episode, score))
# env.close()
# Out:
# Episode: 1  SCore: [200.]
# Episode: 2  SCore: [200.]
# Episode: 3  SCore: [200.]
# Episode: 4  SCore: [200.]
# Episode: 5  SCore: [200.]
# Episode: 6  SCore: [200.]
# Episode: 7  SCore: [200.]
# Episode: 8  SCore: [200.]
# Episode: 9  SCore: [191.]
# Episode: 10  SCore: [200.]

# %%
env.close()

# %% [markdown]
# # Tensorboard

# %%
training_log_path= os.path.join(log_path, 'PPO2')

# %%
training_log_path
# Out:
# 'training\\Logs\\PPO2'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# ^C

# %% [markdown]
# # Callback

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('training', 'Saved_models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold = 200, verbose = 1)
eval_callback = EvalCallback(env, 
                            callback_on_new_best = stop_callback,
                            eval_freq = 10000,
                            best_model_save_path=save_path,
                            verbose = 1)

# %%
model = PPO("MlpPolicy", env, verbose =1, tensorboard_log= log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps = 20000, callback= eval_callback)
# Out:
# Logging to training\Logs\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 3180 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1810        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008704608 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000165   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.57        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 55          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1433        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009774132 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.0716      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 40.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1404        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008130675 |
# |    clip_fraction        | 0.0805      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 62.2        |
# -----------------------------------------
# C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0088972505 |
# |    clip_fraction        | 0.0901       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.609       |
# |    explained_variance   | 0.296        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0171      |
# |    value_loss           | 67.2         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# # Changing Policies

# %%
net_arch = [dict(pi=[128, 128, 128, 128], vf =[128, 128, 128, 128])]

# %%
model = PPO("MlpPolicy", env, verbose =1, tensorboard_log= log_path, policy_kwargs = {'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps = 20000, callback= eval_callback)
# Out:
# Logging to training\Logs\PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 2488 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017074589 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | -0.00338    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 20.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1020        |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015623959 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 30.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 910         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013980839 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 44          |
# -----------------------------------------
# C:\Users\AAKASH AGARWAL\AppData\Local\Programs\Python\Python39\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009163842 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.527       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 39.5        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 869   |
# |    iterations      | 5     |
# |    time_elapsed    | 11    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011060787 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00928    |
# |    value_loss           | 17.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008290751 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.53        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00625    |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 839         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004739834 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.173       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000422   |
# |    value_loss           | 5.6         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005881492 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.358       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 3.75        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.010324314 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.322       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 2.45        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 818   |
# |    iterations      | 10    |
# |    time_elapsed    | 25    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# # Alternate algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN("MlpPolicy", env, verbose =1, tensorboard_log= log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 10003    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 90       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 10357    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 145      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 11696    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 269      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 11587    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 336      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11285    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 11591    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 510      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.704    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 11773    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 624      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11354    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 704      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11289    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.577    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11265    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 890      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 10817    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 952      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 10959    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1096     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 10681    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 10613    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1263     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 10698    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 10757    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 10794    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.249    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 10761    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.225    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 10736    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.192    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 10765    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.147    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 10878    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0951   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11011    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 10999    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11143    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11134    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11165    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2233     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11114    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2323     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 11213    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2411     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 11261    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 11323    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 11305    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2668     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 11436    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2802     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 11479    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 11518    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 11594    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 11633    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3176     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 11696    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 11711    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 11798    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 11934    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3652     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 11913    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 11943    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 12042    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3926     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 12024    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 11877    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4086     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 11727    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 11701    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 11673    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 11642    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 11683    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 11704    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 11706    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 11702    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 11740    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4837     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 11754    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 11743    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4991     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 11754    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5078     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 11737    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 11725    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 11723    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 11764    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5388     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 11758    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 11800    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 11802    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 11787    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 11829    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 11850    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 11835    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 11855    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 11879    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 11867    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 11924    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 11890    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 11886    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 11932    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6706     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 11929    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 11956    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 11953    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 11874    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7113     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 11812    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 11792    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7288     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 11793    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 11795    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 11839    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7589     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 11846    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 11905    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 11983    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8017     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 11974    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 11963    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 11950    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8234     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 11943    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8301     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 11911    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 11895    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 11902    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8546     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 11910    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8623     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 11891    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 11893    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 11866    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 11809    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 11801    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 11752    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 11731    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 11736    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9225     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 11696    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 11696    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 11681    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 11666    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9543     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 11610    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9625     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 11592    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 11540    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 11504    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 11312    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 11227    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 11136    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 11127    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 11080    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 11064    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10556    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 11026    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10630    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 11001    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 11000    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 10943    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 10875    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 10852    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 10787    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 10754    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 10717    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 10696    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 10648    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 10646    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11669    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 10630    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 10598    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 10548    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 10522    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 10495    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 10491    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 10465    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 10441    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 10401    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12357    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 10388    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 10368    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 10377    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 10367    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12711    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 10360    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 10358    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 10336    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12962    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 10345    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 10323    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 10305    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 10308    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 10289    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 10269    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 10249    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13611    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 9914     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 9909     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 9886     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 9875     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 9851     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 9831     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15651    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 9802     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15724    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 9788     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15828    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 9773     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 9762     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15982    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 9740     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16052    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 9714     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 9711     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 9723     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 9714     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 9699     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 9696     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16542    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 9703     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16631    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 9710     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 9705     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 9705     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 9709     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16973    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 9708     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 9713     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 9735     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 9751     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 9753     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 9763     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 9779     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 9781     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17821    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 9793     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 9804     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 9816     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18112    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 9832     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 9825     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 9838     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 9844     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 9877     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 9899     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 9897     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 9899     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 9905     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 9908     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 9902     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19329    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 9907     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19409    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 9910     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 9925     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19603    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 9940     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 9944     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 9947     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19885    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 9953     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 19987    |
# ----------------------------------
